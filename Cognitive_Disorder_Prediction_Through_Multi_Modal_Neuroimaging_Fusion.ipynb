# %% [markdown]
# <a href="https://colab.research.google.com/github/akinolanath5519/Predicting-Cognitive-Disorder-using-Multimodal-Fusion/blob/main/Cognitive_Disorder_Prediction_Through_Multi_Modal_Neuroimaging_Fusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import tensorflow as tf
import zipfile
import os

# %%
# !ls /content
# Out:
# alzheimer_model.h5  gdrive  sample_data

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
images=tf.keras.preprocessing.image_dataset_from_directory("/content/gdrive/MyDrive/Alzheimer_s Dataset/train")
# Out:
# Found 5121 files belonging to 4 classes.

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

print(tf.__version__)
# Out:
# Number of replicas: 1
# 2.15.0

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
IMAGE_SIZE = [176, 208]
EPOCHS = 100

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/gdrive/MyDrive/Alzheimer_s Dataset/train",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/gdrive/MyDrive/Alzheimer_s Dataset/train",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)
# Out:
# Found 5121 files belonging to 4 classes.
# Using 4097 files for training.
# Found 5121 files belonging to 4 classes.
# Using 1024 files for validation.

# %%
class_names = ['MildDementia', 'ModerateDementia', 'NonDementia', 'VeryMildDementia']
train_ds.class_names = class_names
val_ds.class_names = class_names
NUM_CLASSES = len(class_names)

# %% [markdown]
# #Visualize the data

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(train_ds.class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# # Feature Engineering

# %%
def one_hot_label(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label

train_ds = train_ds.map(one_hot_label, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(one_hot_label, num_parallel_calls=AUTOTUNE)

# %%
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Building the model

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )

    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])

    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(*IMAGE_SIZE, 3)),

        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),

        conv_block(32),
        conv_block(64),

        conv_block(128),
        tf.keras.layers.Dropout(0.2),

        conv_block(256),
        tf.keras.layers.Dropout(0.2),

        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),

        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])

    return model

# %%
with strategy.scope():
    model = build_model()

    METRICS = [tf.keras.metrics.AUC(name='auc')]

    model.compile(
        optimizer='adam',
        loss=tf.losses.CategoricalCrossentropy(),
        metrics=METRICS
    )

# %% [markdown]
# # Training the Model
# To more efficiently train our model. We will be using callbacks to adjust our learning rate and to stop our model once it converges.
#
# The learning rate is a very important hyperparameter in the model. Having a LR that is too high will prevent the model from converging. Having a LR that is too slow will make the process too long. Stopping our model early is one mechanism that prevents overfitting.

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("alzheimer_model.h5",
                                                    save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler],
    epochs=EPOCHS
)
# Out:
# Epoch 1/100
# 257/257 [==============================] - 31s 81ms/step - loss: 1.1090 - auc: 0.7822 - val_loss: 2.8773 - val_auc: 0.7220 - lr: 0.0100
# Epoch 2/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9933 - auc: 0.8042 - val_loss: 146.5629 - val_auc: 0.6634 - lr: 0.0089
# Epoch 3/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9816 - auc: 0.8073 - val_loss: 20.9777 - val_auc: 0.6676 - lr: 0.0079
# Epoch 4/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.9640 - auc: 0.8134 - val_loss: 1.0874 - val_auc: 0.7684 - lr: 0.0071
# Epoch 5/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9582 - auc: 0.8170 - val_loss: 1.8938 - val_auc: 0.7758 - lr: 0.0063
# Epoch 6/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.9518 - auc: 0.8165 - val_loss: 1.1262 - val_auc: 0.7494 - lr: 0.0056
# Epoch 7/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.9453 - auc: 0.8203 - val_loss: 1.0449 - val_auc: 0.7809 - lr: 0.0050
# Epoch 8/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9456 - auc: 0.8217 - val_loss: 1.0879 - val_auc: 0.7662 - lr: 0.0045
# Epoch 9/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.9380 - auc: 0.8247 - val_loss: 0.9901 - val_auc: 0.8070 - lr: 0.0040
# Epoch 10/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9501 - auc: 0.8209 - val_loss: 2.4205 - val_auc: 0.7525 - lr: 0.0035
# Epoch 11/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9511 - auc: 0.8181 - val_loss: 1.7403 - val_auc: 0.7825 - lr: 0.0032
# Epoch 12/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.9471 - auc: 0.8199 - val_loss: 1.0475 - val_auc: 0.7844 - lr: 0.0028
# Epoch 13/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.9305 - auc: 0.8284 - val_loss: 1.1490 - val_auc: 0.7526 - lr: 0.0025
# Epoch 14/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9298 - auc: 0.8299 - val_loss: 3.8231 - val_auc: 0.7074 - lr: 0.0022
# Epoch 15/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9333 - auc: 0.8281 - val_loss: 1.1932 - val_auc: 0.8138 - lr: 0.0020
# Epoch 16/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9135 - auc: 0.8361 - val_loss: 0.9593 - val_auc: 0.8279 - lr: 0.0018
# Epoch 17/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9047 - auc: 0.8389 - val_loss: 0.9717 - val_auc: 0.8295 - lr: 0.0016
# Epoch 18/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.9052 - auc: 0.8404 - val_loss: 1.3102 - val_auc: 0.8074 - lr: 0.0014
# Epoch 19/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.8956 - auc: 0.8433 - val_loss: 0.9470 - val_auc: 0.8322 - lr: 0.0013
# Epoch 20/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.8912 - auc: 0.8458 - val_loss: 1.3246 - val_auc: 0.8126 - lr: 0.0011
# Epoch 21/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.8819 - auc: 0.8503 - val_loss: 0.9477 - val_auc: 0.8300 - lr: 0.0010
# Epoch 22/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.8800 - auc: 0.8511 - val_loss: 1.0231 - val_auc: 0.8281 - lr: 8.9125e-04
# Epoch 23/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.8700 - auc: 0.8546 - val_loss: 1.0368 - val_auc: 0.8323 - lr: 7.9433e-04
# Epoch 24/100
# 257/257 [==============================] - 12s 45ms/step - loss: 0.8630 - auc: 0.8562 - val_loss: 0.9448 - val_auc: 0.8375 - lr: 7.0795e-04
# Epoch 25/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.8612 - auc: 0.8582 - val_loss: 0.8611 - val_auc: 0.8569 - lr: 6.3096e-04
# Epoch 26/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.8496 - auc: 0.8619 - val_loss: 0.8784 - val_auc: 0.8543 - lr: 5.6234e-04
# Epoch 27/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.8436 - auc: 0.8641 - val_loss: 0.9559 - val_auc: 0.8455 - lr: 5.0119e-04
# Epoch 28/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.8328 - auc: 0.8687 - val_loss: 0.8276 - val_auc: 0.8703 - lr: 4.4668e-04
# Epoch 29/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.8242 - auc: 0.8714 - val_loss: 0.9973 - val_auc: 0.8427 - lr: 3.9811e-04
# Epoch 30/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.8225 - auc: 0.8721 - val_loss: 0.8828 - val_auc: 0.8572 - lr: 3.5481e-04
# Epoch 31/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.8146 - auc: 0.8745 - val_loss: 0.8335 - val_auc: 0.8640 - lr: 3.1623e-04
# Epoch 32/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.8083 - auc: 0.8770 - val_loss: 0.8534 - val_auc: 0.8669 - lr: 2.8184e-04
# Epoch 33/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7966 - auc: 0.8809 - val_loss: 0.7857 - val_auc: 0.8819 - lr: 2.5119e-04
# Epoch 34/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7912 - auc: 0.8826 - val_loss: 0.7701 - val_auc: 0.8869 - lr: 2.2387e-04
# Epoch 35/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7875 - auc: 0.8834 - val_loss: 0.7844 - val_auc: 0.8813 - lr: 1.9953e-04
# Epoch 36/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7732 - auc: 0.8880 - val_loss: 0.7736 - val_auc: 0.8853 - lr: 1.7783e-04
# Epoch 37/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7687 - auc: 0.8905 - val_loss: 0.7487 - val_auc: 0.8929 - lr: 1.5849e-04
# Epoch 38/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7666 - auc: 0.8908 - val_loss: 0.7470 - val_auc: 0.8937 - lr: 1.4125e-04
# Epoch 39/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7558 - auc: 0.8944 - val_loss: 0.7481 - val_auc: 0.8929 - lr: 1.2589e-04
# Epoch 40/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7510 - auc: 0.8962 - val_loss: 0.7447 - val_auc: 0.8942 - lr: 1.1220e-04
# Epoch 41/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7537 - auc: 0.8953 - val_loss: 0.7376 - val_auc: 0.8967 - lr: 1.0000e-04
# Epoch 42/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7526 - auc: 0.8959 - val_loss: 0.7718 - val_auc: 0.8874 - lr: 8.9125e-05
# Epoch 43/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7450 - auc: 0.8977 - val_loss: 0.7450 - val_auc: 0.8945 - lr: 7.9433e-05
# Epoch 44/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7414 - auc: 0.8984 - val_loss: 0.7378 - val_auc: 0.8970 - lr: 7.0795e-05
# Epoch 45/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7427 - auc: 0.8979 - val_loss: 0.7316 - val_auc: 0.8988 - lr: 6.3096e-05
# Epoch 46/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7383 - auc: 0.9000 - val_loss: 0.7228 - val_auc: 0.9023 - lr: 5.6234e-05
# Epoch 47/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7348 - auc: 0.9003 - val_loss: 0.7227 - val_auc: 0.9023 - lr: 5.0119e-05
# Epoch 48/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7294 - auc: 0.9016 - val_loss: 0.7226 - val_auc: 0.9017 - lr: 4.4668e-05
# Epoch 49/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7190 - auc: 0.9052 - val_loss: 0.7243 - val_auc: 0.9012 - lr: 3.9811e-05
# Epoch 50/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7295 - auc: 0.9023 - val_loss: 0.7182 - val_auc: 0.9031 - lr: 3.5481e-05
# Epoch 51/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7265 - auc: 0.9026 - val_loss: 0.7217 - val_auc: 0.9019 - lr: 3.1623e-05
# Epoch 52/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7350 - auc: 0.9005 - val_loss: 0.7164 - val_auc: 0.9038 - lr: 2.8184e-05
# Epoch 53/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7208 - auc: 0.9045 - val_loss: 0.7142 - val_auc: 0.9045 - lr: 2.5119e-05
# Epoch 54/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7271 - auc: 0.9030 - val_loss: 0.7135 - val_auc: 0.9048 - lr: 2.2387e-05
# Epoch 55/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7299 - auc: 0.9020 - val_loss: 0.7153 - val_auc: 0.9038 - lr: 1.9953e-05
# Epoch 56/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7206 - auc: 0.9044 - val_loss: 0.7157 - val_auc: 0.9038 - lr: 1.7783e-05
# Epoch 57/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7231 - auc: 0.9036 - val_loss: 0.7110 - val_auc: 0.9055 - lr: 1.5849e-05
# Epoch 58/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7299 - auc: 0.9021 - val_loss: 0.7109 - val_auc: 0.9054 - lr: 1.4125e-05
# Epoch 59/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7282 - auc: 0.9024 - val_loss: 0.7117 - val_auc: 0.9052 - lr: 1.2589e-05
# Epoch 60/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7183 - auc: 0.9053 - val_loss: 0.7116 - val_auc: 0.9052 - lr: 1.1220e-05
# Epoch 61/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7180 - auc: 0.9057 - val_loss: 0.7132 - val_auc: 0.9046 - lr: 1.0000e-05
# Epoch 62/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7161 - auc: 0.9066 - val_loss: 0.7101 - val_auc: 0.9056 - lr: 8.9125e-06
# Epoch 63/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7178 - auc: 0.9061 - val_loss: 0.7117 - val_auc: 0.9051 - lr: 7.9433e-06
# Epoch 64/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7185 - auc: 0.9057 - val_loss: 0.7090 - val_auc: 0.9060 - lr: 7.0795e-06
# Epoch 65/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7214 - auc: 0.9046 - val_loss: 0.7093 - val_auc: 0.9059 - lr: 6.3096e-06
# Epoch 66/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7147 - auc: 0.9064 - val_loss: 0.7123 - val_auc: 0.9049 - lr: 5.6234e-06
# Epoch 67/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7208 - auc: 0.9046 - val_loss: 0.7091 - val_auc: 0.9061 - lr: 5.0119e-06
# Epoch 68/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7228 - auc: 0.9040 - val_loss: 0.7109 - val_auc: 0.9054 - lr: 4.4668e-06
# Epoch 69/100
# 257/257 [==============================] - 11s 42ms/step - loss: 0.7181 - auc: 0.9055 - val_loss: 0.7090 - val_auc: 0.9060 - lr: 3.9811e-06
# Epoch 70/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7127 - auc: 0.9069 - val_loss: 0.7094 - val_auc: 0.9059 - lr: 3.5481e-06
# Epoch 71/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7242 - auc: 0.9036 - val_loss: 0.7101 - val_auc: 0.9056 - lr: 3.1623e-06
# Epoch 72/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7189 - auc: 0.9054 - val_loss: 0.7108 - val_auc: 0.9054 - lr: 2.8184e-06
# Epoch 73/100
# 257/257 [==============================] - 11s 44ms/step - loss: 0.7141 - auc: 0.9071 - val_loss: 0.7084 - val_auc: 0.9062 - lr: 2.5119e-06
# Epoch 74/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7125 - auc: 0.9068 - val_loss: 0.7071 - val_auc: 0.9067 - lr: 2.2387e-06
# Epoch 75/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7129 - auc: 0.9072 - val_loss: 0.7100 - val_auc: 0.9056 - lr: 1.9953e-06
# Epoch 76/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7217 - auc: 0.9048 - val_loss: 0.7122 - val_auc: 0.9049 - lr: 1.7783e-06
# Epoch 77/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7130 - auc: 0.9068 - val_loss: 0.7108 - val_auc: 0.9053 - lr: 1.5849e-06
# Epoch 78/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7198 - auc: 0.9049 - val_loss: 0.7087 - val_auc: 0.9061 - lr: 1.4125e-06
# Epoch 79/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7173 - auc: 0.9055 - val_loss: 0.7103 - val_auc: 0.9057 - lr: 1.2589e-06
# Epoch 80/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7146 - auc: 0.9069 - val_loss: 0.7101 - val_auc: 0.9056 - lr: 1.1220e-06
# Epoch 81/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7171 - auc: 0.9062 - val_loss: 0.7082 - val_auc: 0.9062 - lr: 1.0000e-06
# Epoch 82/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7217 - auc: 0.9048 - val_loss: 0.7094 - val_auc: 0.9057 - lr: 8.9125e-07
# Epoch 83/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7221 - auc: 0.9036 - val_loss: 0.7083 - val_auc: 0.9063 - lr: 7.9433e-07
# Epoch 84/100
# 257/257 [==============================] - 11s 43ms/step - loss: 0.7225 - auc: 0.9039 - val_loss: 0.7093 - val_auc: 0.9058 - lr: 7.0795e-07

# %% [markdown]
# #Visualize Model Metrics
# Let's graph the ROC AUC metric and loss after each epoch for the training and validation data. Although we didn't use a random seed for our notebook, the results may slightly vary, generally the scores for the validataion data is similar, if not better, than the training dataset.

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['auc', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
